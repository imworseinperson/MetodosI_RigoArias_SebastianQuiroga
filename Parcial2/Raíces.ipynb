# %%
#Código base

import sympy as sp
import numpy as np

x = sp.Symbol('x',real=True)

def GetLaguerre(n,x):
    
    if n==0:
        poly = sp.Number(1)
    elif n==1:
        poly = 1 - x
    else:
        poly = (((2*(n-1)+1-x)*GetLaguerre(n-1,x))-((n-1)*(GetLaguerre(n-2,x))))/n
   
    return sp.expand(poly,x)

def GetDLaguerre(n,x):
    Pn = GetLaguerre(n,x)
    return sp.diff(Pn,x)

def GetNewton(f,df,xn,itmax=10000,precision=1e-14):
    
    error = 1.
    it = 0
    
    while error >= precision and it < itmax:
        
        try:
            
            xn1 = xn - f(xn)/df(xn)
            
            error = np.abs(f(xn)/df(xn))
            
        except ZeroDivisionError:
            print('Zero Division')
            
        xn = xn1
        it += 1
        
    if it == itmax:
        return False
    else:
        return xn

def GetRoots(f,df,x,tolerancia = 10):
    
    Roots = np.array([])
    
    for i in x:
        
        root = GetNewton(f,df,i)

        if  type(root)!=bool:
            croot = np.round( root, tolerancia )
            
            if croot not in Roots:
                Roots = np.append(Roots, croot)
                
    Roots.sort()
    
    return Roots

def GetAllRootsGLag(n):

    xn = np.linspace(0,(n+((n-1)*np.sqrt(n))),100)
    
    Laguerre = []
    DLaguerre = []
    
    for i in range(n+1):
        Laguerre.append(GetLaguerre(i,x))
        DLaguerre.append(GetDLaguerre(i,x))
    
    poly = sp.lambdify([x],Laguerre[n],'numpy')
    Dpoly = sp.lambdify([x],DLaguerre[n],'numpy')
    Roots = GetRoots(poly,Dpoly,xn)

    if len(Roots) != n:
        ValueError('El número de raíces debe ser igual al n del polinomio.')
    
    return Roots

# %%
#Respuesta
print('1: ', GetAllRootsGLag(1), '2: ', GetAllRootsGLag(2), 
      '3: ', GetAllRootsGLag(3), '4: ', GetAllRootsGLag(4), 
      '5: ', GetAllRootsGLag(5), '6: ', GetAllRootsGLag(6), 
      '7: ', GetAllRootsGLag(7), '8: ', GetAllRootsGLag(8), 
      '9: ', GetAllRootsGLag(9), '10: ', GetAllRootsGLag(10), 
      '11: ', GetAllRootsGLag(11), '12: ', GetAllRootsGLag(12), 
      '13: ', GetAllRootsGLag(13), '14: ', GetAllRootsGLag(14), 
      '15: ', GetAllRootsGLag(15), '16: ', GetAllRootsGLag(16), 
      '17: ', GetAllRootsGLag(17), '18: ', GetAllRootsGLag(18), 
      '19: ', GetAllRootsGLag(19), '20: ', GetAllRootsGLag(20))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9820\3066315747.py in <module>
#       7       '11: ', GetAllRootsGLag(11), '12: ', GetAllRootsGLag(12),
#       8       '13: ', GetAllRootsGLag(13), '14: ', GetAllRootsGLag(14),
# ----> 9       '15: ', GetAllRootsGLag(15), '16: ', GetAllRootsGLag(16),
#      10       '17: ', GetAllRootsGLag(17), '18: ', GetAllRootsGLag(18),
#      11       '19: ', GetAllRootsGLag(19), '20: ', GetAllRootsGLag(20))
#
# ~\AppData\Local\Temp\ipykernel_9820\1477898082.py in GetAllRootsGLag(n)
#      76     poly = sp.lambdify([x],Laguerre[n],'numpy')
#      77     Dpoly = sp.lambdify([x],DLaguerre[n],'numpy')
# ---> 78     Roots = GetRoots(poly,Dpoly,xn)
#      79
#      80     if len(Roots) != n:
#
# ~\AppData\Local\Temp\ipykernel_9820\1477898082.py in GetRoots(f, df, x, tolerancia)
#      51     for i in x:
#      52
# ---> 53         root = GetNewton(f,df,i)
#      54
#      55         if  type(root)!=bool:
#
# ~\AppData\Local\Temp\ipykernel_9820\1477898082.py in GetNewton(f, df, xn, itmax, precision)
#      30         try:
#      31
# ---> 32             xn1 = xn - f(xn)/df(xn)
#      33
#      34             error = np.abs(f(xn)/df(xn))
#
# <lambdifygenerated-111> in _lambdifygenerated(x)
#       1 def _lambdifygenerated(x):
# ----> 2     return (1/20922789888000)*x**16 - 1/81729648000*x**15 + (1/726485760)*x**14 - 1/11119680*x**13 + (13/3421440)*x**12 - 13/118800*x**11 + (143/64800)*x**10 - 143/4536*x**9 + (143/448)*x**8 - 143/63*x**7 + (1001/90)*x**6 - 182/5*x**5 + (455/6)*x**4 - 280/3*x**3 + 60*x**2 - 16*x + 1
#
# KeyboardInterrupt:
